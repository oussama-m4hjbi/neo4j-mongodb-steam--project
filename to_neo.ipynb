# %%
from pymongo import MongoClient
import modin.pandas as pd

import numpy as np


client = MongoClient("mongodb+srv://************************)
db = client["uhei"]
collection = db["users"]

# %%
# Convert the cursor to a list
users = collection.find()
# Convert the cursor to a list
users_list = list(users)
users_list
# Out:
# [{'_id': ObjectId('63ca991e62055269121c17e2'),
#   'appid': 230410,
#   'name': 'alessandro',
#   'playtime_forever': 25,
#   'img_icon_url': '22064646470f4c53388ba87774c7ac10f0a91ffa',
#   'has_community_visible_stats': True,
#   'playtime_windows_forever': 0,
#   'playtime_mac_forever': 0,
#   'playtime_linux_forever': 0,
#   'rtime_last_played': 1537696050,
#   'content_descriptorids': [2, 5]},
#  {'_id': ObjectId('63ca991e62055269121c17e3'),
#   'appid': 241600,
#   'name': 'alessandro',
#   'playtime_forever': 3290,
#   'img_icon_url': '15272c0c114b2c715e1baf0cca44319deae74731',
#   'has_community_visible_stats': True,
#   'playtime_windows_forever': 1733,
#   'playtime_mac_forever': 0,
#   'playtime_linux_forever': 0,
#   'rtime_last_played': 1591120406},
#  {'_id': ObjectId('63ca991e62055269121c17e4'),
#   'appid': 268910,
#   'name': 'alessandro',
#   'playtime_forever': 86,
#   'img_icon_url': 'c19f1bd916b6d171e94089d03112ec4e4e4da84e',
# ...

# %%
df1 = pd.DataFrame(users_list)
pd.set_option('display.max_columns', None)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   _id                          569 non-null    object
#  1   appid                        569 non-null    int64
#  2   name                         569 non-null    object
#  3   playtime_forever             569 non-null    int64
#  4   img_icon_url                 569 non-null    object
#  5   has_community_visible_stats  420 non-null    object
#  6   playtime_windows_forever     569 non-null    int64
#  7   playtime_mac_forever         569 non-null    int64
#  8   playtime_linux_forever       569 non-null    int64
#  9   rtime_last_played            569 non-null    int64
#  10  content_descriptorids        86 non-null     object
#  11  has_leaderboards             43 non-null     object
#  12  playtime_2weeks              15 non-null     float64
# ...

# %%
client = MongoClient("mongodb+srv://oussama:oussama12345@cluster11.177q8xl.mongodb.net/test")
db = client["uhei"]
collection = db["vidd"]
# Retrieve all documents that have an "id" value in the "ht" array
data = collection.find()
import pandas as pd
df = pd.DataFrame(list(data))
df
# Iterate through the documents and print their contents
# Out:
#                             _id     App ID                            Name  \
# 0      63ce61cfcb615487b08f0b54       10.0                  Counter-Strike
# 1      63ce61cfcb615487b08f0b55  1000000.0                       ASCENXION
# 2      63ce61cfcb615487b08f0b56  1000010.0                     Crown Trick
# 3      63ce61cfcb615487b08f0b57  1000030.0     Cook, Serve, Delicious! 3?!
# 4      63ce61cfcb615487b08f0b58  1000040.0                            ????
# ...                         ...        ...                             ...
# 55701  63ce61edcb615487b08fe4e9   999880.0     NASA's Exoplanet Excursions
# 55702  63ce61edcb615487b08fe4ea   999890.0                          Bruken
# 55703  63ce61edcb615487b08fe4eb   999900.0               Studio by RADiCAL
# 55704  63ce61edcb615487b08fe4ec   999930.0  Fantasy Sino-Japanese War ????
# 55705  63ce61edcb615487b08fe4ed   999990.0                   Bouncing Hero
#
#                                        Short Description  \
# ...

# %%
df['App ID'] = df['App ID'].fillna(0).astype(int)

# %%
df_merged = pd.merge(df1, df, left_on='appid', right_on='App ID')
df_merged
# Out:
#                         _id_x    appid        name  playtime_forever  \
# 0    63ca991e62055269121c17e2   230410  alessandro                25
# 1    63ca992662055269121c1802   230410     daniele               190
# 2    63ca993b62055269121c1923   230410     Edoardo              5153
# 3    63ca99c962055269121c1a13   230410    Riccardo               466
# 4    63ca991e62055269121c17e3   241600  alessandro              3290
# ..                        ...      ...         ...               ...
# 502  63ca996062055269121c19fc   736220    Gianluca                90
# 503  63ca996062055269121c19fd  1410710    Gianluca              1653
# 504  63ca997362055269121c19ff   364470      Pietro               182
# 505  63ca997362055269121c1a05   744900      Pietro               126
# 506  63ca997362055269121c1a08   790600      Pietro               110
#
#                                  img_icon_url has_community_visible_stats  \
# ...

# %%
df_merged.to_csv('data.csv', index=False)

# %%
####### import data into neo4j ##### 

from neo4j import GraphDatabase

transaction_list = df_merged.values.tolist()

transaction_execution_commands = []

for i in transaction_list:
    neo4j_create_statemenet = "create (t:player {transaction_id:" + str(i[2])
    transaction_execution_commands.append(neo4j_create_statemenet)

    
def execute_transactions(transaction_execution_commands):
    data_base_connection = GraphDatabase.driver(uri = "neo4j+s://9c195baa.databases.neo4j.io", auth=("neo4j", "0nOtQ2JP6EQA5rOcTcA2FQ4gr6-wjvE2hdPgmHklFjE"))
    session = data_base_connection.session()    
    for i in transaction_execution_commands:
        session.run(i)

        
execute_transactions(transaction_execution_commands)
# Out:
# ---------------------------------------------------------------------------
# CypherSyntaxError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23424/2033422214.py in <module>
#      19
#      20
# ---> 21 execute_transactions(transaction_execution_commands)
#
# ~\AppData\Local\Temp/ipykernel_23424/2033422214.py in execute_transactions(transaction_execution_commands)
#      16     session = data_base_connection.session()
#      17     for i in transaction_execution_commands:
# ---> 18         session.run(i)
#      19
#      20
#
# c:\Users\oussa\anaconda3\lib\site-packages\neo4j\_sync\work\session.py in run(self, query, parameters, **kwargs)
#     287         bookmarks = self._get_bookmarks()
#     288         parameters = dict(parameters or {}, **kwargs)
# --> 289         self._auto_result._run(
#     290             query, parameters, self._config.database,
# ...

# %%
from py2neo import Graph
import pandas as pd

# Connect to the Neo4j database
data_base_connection = GraphDatabase.driver(uri = "neo4j+s://9c195baa.databases.neo4j.io", auth=("neo4j", "0nOtQ2JP6EQA5rOcTcA2FQ4gr6-wjvE2hdPgmHklFjE"))

# Read the DataFrame


# Iterate through the rows in the DataFrame
for i, row in df_merged.iterrows():
    # Create a node in Neo4j for each row
    query = """
            CREATE (n:Label { """
    for c in df_merged.columns:
        query += f"{c}: {{{c}}},"
    query = query[:-1] + "})"
    graph.run(query, **row.to_dict())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6380/2838174263.py in <module>
#      16         query += f"{c}: {{{c}}},"
#      17     query = query[:-1] + "})"
# ---> 18     graph.run(query, **row.to_dict())
#
# AttributeError: 'Neo4jDriver' object has no attribute 'run'
